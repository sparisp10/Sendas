# %%
import pandas as pd
import numpy as np
import datetime as dt
from FuncionesSendas import *
from scipy.stats import norm
import plotly.graph_objs as go

# %%
Fecha=dt.date(2022,1,31)
df=simul(Fecha,5)
grafica(Fecha,'EURCOP')
